# %%
import pandas as pd

# %%
df = pd.DataFrame([(1,2,3),(4,5,6),(7,8,9)], columns=['A','B','C'], index=['X', 'Y','Z'])

# %%
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df = pd.read_csv('/content/athlete_events.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.sample(10)
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 171105   85988         Holger Louis Nielsen   M  29.0     NaN     NaN
# 124614   62931       Pawe Jzef Korzeniowski   M  19.0   192.0    82.0
# 51876    26664      Lenika De Simone Blanco   F  19.0   152.0    46.0
# 82628    41975     Joseph Michael Gostigian   M  29.0   178.0    73.0
# 115608   58574     Frederick Septimus Kelly   M  26.0     NaN    77.0
# 97686    49445                    Poul Holm   M  19.0     NaN     NaN
# 196141   98476     Soundarajan Arokia Rajiv   M  25.0   175.0    65.0
# 214304  107593  Edeltraud "Traudl" Schubert   F  18.0   162.0    52.0
# 12250     6658            Ren Badell Pollar   M  24.0   175.0    76.0
# 176426   88711      Ivn Jos Olivares Alvrez   M  30.0   195.0    85.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 171105         Denmark  DEN  1896 Summer  1896  Summer          Athina
# ...

# %%
df.loc[4,"Age"]
# Out:
# 21.0

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#             ID                        Name Sex   Age  Height  Weight  \
# 257054  128719      John Quincy Adams Ward   M  97.0     NaN     NaN
# 98118    49663               Winslow Homer   M  96.0     NaN     NaN
# 60863    31173  Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# 60861    31173  Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# 60862    31173  Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# ...        ...                         ...  ..   ...     ...     ...
# 270679  135368           Antonio A. Zucchi   M   NaN     NaN     NaN
# 270774  135416                   Star Zulu   M   NaN     NaN     NaN
# 270793  135426                Max Zumstein   M   NaN     NaN     NaN
# 270804  135434          Edmundo Ziga Erraz   M   NaN   180.0    95.0
# 270805  135435                  Faelo Ziga   M   NaN     NaN     NaN
#
#                  Team  NOC        Games  Year  Season         City  \
# 257054  United States  USA  1928 Summer  1928  Summer    Amsterdam
# ...

# %%
for index, row in df.iterrows():
  print(index, row['Age'])

# %%
df.loc[df["Height"] > 215, ["Name","Height"]]
# Out:
#                                                      Name  Height
# 14132                                         Stanko Bara   217.0
# 17669                                      Gunther Behnke   221.0
# 22743                                            Uwe Blab   218.0
# 22744                                            Uwe Blab   218.0
# 32376                                Tommy Loren Burleson   223.0
# 34307                              Andrew "Andy" Campbell   218.0
# 34308                              Andrew "Andy" Campbell   218.0
# 38381                              Tyson Cleotis Chandler   216.0
# 47982                                 Paulo Csar da Silva   217.0
# 59371                              Roberto Dueas Hernndez   221.0
# 59372                              Roberto Dueas Hernndez   221.0
# 80447                                 Andreas Glyniadakis   216.0
# 87972                                    Hamed E. Haddadi   218.0
# ...

# %%
df[(df["Height"] > 215) & (df['City']=='London')]
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 38381    19736          Tyson Cleotis Chandler   M  29.0   216.0   107.0
# 156025   78340                  Salah Al-Mejri   M  26.0   216.0   110.0
# 164743   82731        Timofey Pavlovich Mozgov   M  26.0   216.0   113.0
# 166544   83657  Dmitry Aleksandrovich Musersky   M  23.0   219.0   104.0
# 269053  134621                    Zhang Zhaoxu   M  24.0   221.0   110.0
#
#                  Team  NOC        Games  Year  Season    City       Sport  \
# 38381   United States  USA  2012 Summer  2012  Summer  London  Basketball
# 156025        Tunisia  TUN  2012 Summer  2012  Summer  London  Basketball
# 164743         Russia  RUS  2012 Summer  2012  Summer  London  Basketball
# 166544         Russia  RUS  2012 Summer  2012  Summer  London  Volleyball
# 269053          China  CHN  2012 Summer  2012  Summer  London  Basketball
#
#                               Event   Medal
# ...

# %%
df[df['Name'].str.contains("Timofey | Dmitry", case=False)]
# Out:
#             ID                                    Name Sex   Age  Height  \
# 50033    25758              Sergey Dmitryevich Davydov   M  22.0   159.0
# 50034    25758              Sergey Dmitryevich Davydov   M  26.0   159.0
# 54601    28005      Timofey Aleksandrovich Deynichenko   M  25.0   186.0
# 54602    28005      Timofey Aleksandrovich Deynichenko   M  29.0   186.0
# 56432    28913                     Sergey Dmitryaychev   M  25.0   183.0
# 82263    41781         Timofey Dmitriyevich Gordeychik   M  26.0   171.0
# 113490   57497  Olga Dmitryievna Karasyova (Kharlova-)   F  19.0   164.0
# 113491   57497  Olga Dmitryievna Karasyova (Kharlova-)   F  19.0   164.0
# 113492   57497  Olga Dmitryievna Karasyova (Kharlova-)   F  19.0   164.0
# 113493   57497  Olga Dmitryievna Karasyova (Kharlova-)   F  19.0   164.0
# 113494   57497  Olga Dmitryievna Karasyova (Kharlova-)   F  19.0   164.0
# 113495   57497  Olga Dmitryievna Karasyova (Kharlova-)   F  19.0   164.0
# ...

# %%
df[df['City'].isin(["London","Los Angeles"]) & (df['Name'].str.startswith("Timofey "))]
# Out:
#            ID                                Name Sex   Age  Height  Weight  \
# 54601   28005  Timofey Aleksandrovich Deynichenko   M  25.0   186.0    98.0
# 82263   41781     Timofey Dmitriyevich Gordeychik   M  26.0   171.0    63.0
# 164743  82731            Timofey Pavlovich Mozgov   M  26.0   216.0   113.0
#
#            Team  NOC        Games  Year  Season    City       Sport  \
# 54601   Belarus  BLR  2012 Summer  2012  Summer  London   Wrestling
# 82263   Belarus  BLR  2012 Summer  2012  Summer  London      Diving
# 164743   Russia  RUS  2012 Summer  2012  Summer  London  Basketball
#
#                                            Event   Medal
# 54601   Wrestling Men's Heavyweight, Greco-Roman     NaN
# 82263                      Diving Men's Platform     NaN
# 164743               Basketball Men's Basketball  Bronze

# %%
df.query('City == "Amsterdam" and Age > 20')
# Out:
#             ID                  Name Sex   Age  Height  Weight  \
# 133         47  Erling Rudolf Aastad   M  30.0   177.0    74.0
# 273        142   David "Dave" Abbott   M  26.0   183.0    75.0
# 459        255   Mahmoud Ahmed Abdin   M  21.0     NaN     NaN
# 460        255   Mahmoud Ahmed Abdin   M  21.0     NaN     NaN
# 664        385    Max "Xam" Abegglen   M  26.0     NaN     NaN
# ...        ...                   ...  ..   ...     ...     ...
# 270572  135323  Franois "Frnz" Zuang   M  33.0     NaN     NaN
# 270573  135323  Franois "Frnz" Zuang   M  33.0     NaN     NaN
# 270595  135336  Feliks Grzegorz uber   M  22.0   167.0    60.0
# 270962  135499     Alberts Zvejnieks   M  25.0     NaN     NaN
# 271100  135561         Frantiek Zyka   M  26.0     NaN     NaN
#
#                   Team  NOC        Games  Year  Season       City       Sport  \
# 133             Norway  NOR  1928 Summer  1928  Summer  Amsterdam   Athletics
# ...

# %%
df['Age'].between(20,30)
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 271111     True
# 271112     True
# 271113     True
# 271114     True
# 271115    False
# Name: Age, Length: 271116, dtype: bool

# %%
df['Age'] = 24  #update the value of age to 24

# %%
import numpy as np
a = df['New'] = np.where(df['Age'] > 20, 'Yes', 'No')

# %%
df1= df.drop(columns=['Age']) #inplace = true it will clear the column in original dataset

# %%
df1
# Out:
#             ID                      Name Sex  Height  Weight            Team  \
# 0            1                 A Dijiang   M   180.0    80.0           China
# 1            2                  A Lamusi   M   170.0    60.0           China
# 2            3       Gunnar Nielsen Aaby   M     NaN     NaN         Denmark
# 3            4      Edgar Lindenau Aabye   M     NaN     NaN  Denmark/Sweden
# 4            5  Christine Jacoba Aaftink   F   185.0    82.0     Netherlands
# ...        ...                       ...  ..     ...     ...             ...
# 271111  135569                Andrzej ya   M   179.0    89.0        Poland-1
# 271112  135570                  Piotr ya   M   176.0    59.0          Poland
# 271113  135570                  Piotr ya   M   176.0    59.0          Poland
# 271114  135571        Tomasz Ireneusz ya   M   185.0    96.0          Poland
# 271115  135571        Tomasz Ireneusz ya   M   185.0    96.0          Poland
#
# ...

# %%
df1['Age']=22

# %%
df1
# Out:
#             ID                      Name Sex  Height  Weight            Team  \
# 0            1                 A Dijiang   M   180.0    80.0           China
# 1            2                  A Lamusi   M   170.0    60.0           China
# 2            3       Gunnar Nielsen Aaby   M     NaN     NaN         Denmark
# 3            4      Edgar Lindenau Aabye   M     NaN     NaN  Denmark/Sweden
# 4            5  Christine Jacoba Aaftink   F   185.0    82.0     Netherlands
# ...        ...                       ...  ..     ...     ...             ...
# 271111  135569                Andrzej ya   M   179.0    89.0        Poland-1
# 271112  135570                  Piotr ya   M   176.0    59.0          Poland
# 271113  135570                  Piotr ya   M   176.0    59.0          Poland
# 271114  135571        Tomasz Ireneusz ya   M   185.0    96.0          Poland
# 271115  135571        Tomasz Ireneusz ya   M   185.0    96.0          Poland
#
# ...

# %%
df['Flag']=df['Age'].apply(lambda x: 1 if x>20 else 0)

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
def categorize(row):
  if row['Weight'] < 60:
    return 'underweight'
  elif row['Weight'] >= 60 and row['Weight'] < 80:
    return 'normal'
  else:
    return 'overweight'

# %%
df1['category'] = df.apply(categorize, axis=1)

# %%
df1
# Out:
#             ID                      Name Sex  Height  Weight            Team  \
# 0            1                 A Dijiang   M   180.0    80.0           China
# 1            2                  A Lamusi   M   170.0    60.0           China
# 2            3       Gunnar Nielsen Aaby   M     NaN     NaN         Denmark
# 3            4      Edgar Lindenau Aabye   M     NaN     NaN  Denmark/Sweden
# 4            5  Christine Jacoba Aaftink   F   185.0    82.0     Netherlands
# ...        ...                       ...  ..     ...     ...             ...
# 271111  135569                Andrzej ya   M   179.0    89.0        Poland-1
# 271112  135570                  Piotr ya   M   176.0    59.0          Poland
# 271113  135570                  Piotr ya   M   176.0    59.0          Poland
# 271114  135571        Tomasz Ireneusz ya   M   185.0    96.0          Poland
# 271115  135571        Tomasz Ireneusz ya   M   185.0    96.0          Poland
#
# ...

# %%
df2= pd.read_csv('/content/noc_regions.csv')

# %%
df2.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal  New  Flag
# 0       Basketball Men's Basketball   NaN  Yes     1
# ...

# %%
df.loc[[0,1],'Year'] = np.nan

# %%
df.head(25)
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0           China
# 1    2                  A Lamusi   M  23.0   170.0    60.0           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271114 non-null  float64
#  10  Season  271116 non-null  object
#  11  City    271114 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  New     271116 non-null  object
#  16  Flag    271116 non-null  int64
#  17  year    0 non-null       float64
# dtypes: float64(5), int64(2), object(11)
# memory usage: 37.2+ MB

# %%
df.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           2
# Season         0
# City           2
# Sport          0
# Event          0
# Medal     231333
# New            0
# Flag           0
# year      271116
# dtype: int64

# %%
df.fillna(round(df['Year'].mean()))
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0  1978.0  1978.0
# 3            4      Edgar Lindenau Aabye   M  34.0  1978.0  1978.0
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games    Year  Season            City  \
# 0                China  CHN  1992 Summer  1978.0  Summer            1978
# ...

# %%
df[df['Year'].notna()]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games    Year  Season            City  \
# 2              Denmark  DEN  1920 Summer  1920.0  Summer       Antwerpen
# ...

# %%
df.drop(["year"],axis=1)
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games    Year  Season            City  \
# 0                China  CHN  1992 Summer     NaN  Summer             NaN
# ...

# %%
df['City'].value_counts()
# Out:
# City
# London                    22425
# Athina                    15556
# Sydney                    13821
# Atlanta                   13780
# Rio de Janeiro            13688
# Beijing                   13602
# Barcelona                 12976
# Los Angeles               12423
# Seoul                     12037
# Munich                    10304
# Montreal                   8641
# Mexico City                8588
# Helsinki                   8270
# Roma                       8119
# Tokyo                      7702
# Moskva                     7191
# Paris                      7169
# Berlin                     6506
# Amsterdam                  4992
# Sochi                      4891
# Melbourne                  4829
# Vancouver                  4402
# Torino                     4382
# Stockholm                  4338
# Antwerpen                  4292
# Salt Lake City             4109
# Innsbruck                  3639
# Nagano                     3605
# Albertville                3436
# ...

# %%
df[df['City']=='London']['Sport'].value_counts()
# Out:
# Sport
# Athletics                4107
# Gymnastics               2257
# Swimming                 2086
# Shooting                 1220
# Cycling                  1218
# Fencing                  1093
# Rowing                    955
# Football                  757
# Wrestling                 701
# Hockey                    642
# Sailing                   629
# Basketball                574
# Canoeing                  557
# Equestrianism             557
# Boxing                    530
# Art Competitions          471
# Water Polo                441
# Judo                      383
# Weightlifting             372
# Tennis                    370
# Handball                  347
# Diving                    312
# Volleyball                287
# Archery                   277
# Table Tennis              236
# Badminton                 182
# Taekwondo                 128
# Modern Pentathlon         117
# Synchronized Swimming     117
# Triathlon                 110
# Beach Volleyball           96
# ...

# %%
df.groupby('City')['Sport'].value_counts()
# Out:
# City         Sport
# Albertville  Alpine Skiing           750
#              Cross Country Skiing    717
#              Biathlon                457
#              Speed Skating           354
#              Ice Hockey              267
#                                     ...
# Vancouver    Figure Skating          146
#              Nordic Combined         131
#              Luge                    107
#              Curling                  93
#              Skeleton                 47
# Name: count, Length: 794, dtype: int64

# %%
pivot = df.pivot(columns='City', index= 'ID', values='Sport')

# %%
group = df.groupby(['City', 'Sport'])['Name'].value_counts()

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games    Year  Season            City  \
# 0                China  CHN  1992 Summer     NaN  Summer             NaN
# ...
